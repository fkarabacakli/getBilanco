# %%
import pandas as pd

# %%
df = pd.read_excel("path/SASA.xlsx")

# %%
df.set_index('index', inplace=True)

# %%
import commands

# %%
df = commands.Calculation(df)

# %%
df
# Out:
#             03/2024       12/2023       09/2023       06/2023       03/2023  \
# index
# 1A     2.929904e+10  2.878305e+10  2.216284e+10  2.213147e+10  1.564815e+10
# 1AA    6.533311e+09  5.261236e+09  2.315471e+09  4.392746e+09  1.691271e+09
# 1AB    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1AC    8.732081e+09  1.075986e+10  9.420916e+09  7.465424e+09  4.398492e+09
# 1AD    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...             ...           ...           ...           ...           ...
# B2     4.701001e-01  4.337728e-01  2.977532e-01  2.143905e-01  3.237287e-01
# B3     8.871489e-01  7.660755e-01  4.240009e-01  2.728970e-01  4.786965e-01
# B4     2.473617e-01  2.319734e-01  3.511608e-01  5.957120e-01  4.136228e-01
# B5     2.825382e-01  3.342538e-01  3.510860e-01  1.898975e-01  2.626485e-01
# D1     9.960674e-02 -9.553648e-02 -3.350073e-01 -3.470918e-01 -1.148486e-01
#
# ...

# %%
df.loc['C2']
# Out:
# 03/2024    1.221636
# 12/2023    4.304579
# 09/2023    2.811342
# 06/2023    2.091999
# 03/2023    3.270166
#              ...
# 03/2009    1.531766
# 12/2008    8.395703
# 09/2008    4.658363
# 06/2008    3.079828
# 03/2008    1.736185
# Name: C2, Length: 65, dtype: float64
